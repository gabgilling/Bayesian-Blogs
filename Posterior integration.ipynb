# %%
import numpy as np
from scipy.stats import norm, binom
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,1,100)

# %%
norm_prior = norm.pdf(x, loc = 0.5, scale = 0.1)
norm_prior
# Out:
# array([1.48671951e-05, 2.45106104e-05, 3.99989037e-05, 6.46116639e-05,
#        1.03310066e-04, 1.63509589e-04, 2.56160812e-04, 3.97238224e-04,
#        6.09759040e-04, 9.26476353e-04, 1.39341123e-03, 2.07440309e-03,
#        3.05686225e-03, 4.45889725e-03, 6.43795498e-03, 9.20104770e-03,
#        1.30165384e-02, 1.82273110e-02, 2.52649578e-02, 3.46643792e-02,
#        4.70779076e-02, 6.32877643e-02, 8.42153448e-02, 1.10925548e-01,
#        1.44624148e-01, 1.86646099e-01, 2.38432745e-01, 3.01496139e-01,
#        3.77369231e-01, 4.67541424e-01, 5.73380051e-01, 6.96039584e-01,
#        8.36361772e-01, 9.94771388e-01, 1.17117360e+00, 1.36486009e+00,
#        1.57443188e+00, 1.79774665e+00, 2.03189836e+00, 2.27323506e+00,
#        2.51741947e+00, 2.75953371e+00, 2.99422683e+00, 3.21590023e+00,
#        3.41892294e+00, 3.59786558e+00, 3.74773979e+00, 3.86422853e+00,
#        3.94389234e+00, 3.98433802e+00, 3.98433802e+00, 3.94389234e+00,
# ...

# %%
plt.plot(x, norm_prior)

# %%
def joint(n, y, theta):
    return (theta**y) *( (1-theta)**(n-y)) * (norm.pdf(theta, loc = 0.5, scale = 0.1))

# %%
def likelihood(n, y, theta):
    return (theta**y) *( (1-theta)**(n-y))

# %%
plt.plot(x, likelihood(100, 60, x))

# %%
plt.plot(x, joint(100, 60, x))

# %%
from scipy.integrate import simps

# %%
integrate.quad(func = , a = -np.inf, b = np.inf)
# Out:
#   File "<ipython-input-12-8eca4091528f>", line 1
#     integrate.quad(func = , a = -np.inf, b = np.inf)
#                           ^
# SyntaxError: invalid syntax

# %%
simps(joint(100, 60, x), dx=x[99]-x[0])
# Out:
# 1.7313492223393783e-28

# %%
plt.plot(x, joint(100, 60, x) / simps(joint(100, 60, x), dx=x[1]-x[0]) )

# %%
joint(100, 60, x) / simps(joint(100, 60, x), dx=x[1]-x[0])
# Out:
# array([0.00000000e+00, 1.70658614e-95, 2.13033674e-77, 8.35923604e-67,
#        2.75687699e-59, 1.86461292e-53, 1.07309140e-48, 1.12247735e-44,
#        3.35694494e-41, 3.84429177e-38, 2.05783539e-35, 5.93597693e-33,
#        1.02482992e-30, 1.14682648e-28, 8.84948838e-27, 4.94555831e-25,
#        2.08232838e-23, 6.82249207e-22, 1.78649044e-20, 3.82322645e-19,
#        6.81446245e-18, 1.02799879e-16, 1.33079802e-15, 1.49615468e-14,
#        1.47603587e-13, 1.28949388e-12, 1.00556984e-11, 7.04917870e-11,
#        4.47006023e-10, 2.57841387e-09, 1.35960437e-08, 6.58298910e-08,
#        2.93843467e-07, 1.21352341e-06, 4.65180627e-06, 1.65997220e-05,
#        5.52875006e-05, 1.72278297e-04, 5.03317736e-04, 1.38134398e-03,
#        3.56752143e-03, 8.68396189e-03, 1.99511258e-02, 4.33173660e-02,
#        8.89792089e-02, 1.73092086e-01, 3.19157588e-01, 5.58211890e-01,
#        9.26696230e-01, 1.46100671e+00, 2.18842010e+00, 3.11541689e+00,
# ...

# %%
x
# Out:
# array([0.        , 0.01010101, 0.02020202, 0.03030303, 0.04040404,
#        0.05050505, 0.06060606, 0.07070707, 0.08080808, 0.09090909,
#        0.1010101 , 0.11111111, 0.12121212, 0.13131313, 0.14141414,
#        0.15151515, 0.16161616, 0.17171717, 0.18181818, 0.19191919,
#        0.2020202 , 0.21212121, 0.22222222, 0.23232323, 0.24242424,
#        0.25252525, 0.26262626, 0.27272727, 0.28282828, 0.29292929,
#        0.3030303 , 0.31313131, 0.32323232, 0.33333333, 0.34343434,
#        0.35353535, 0.36363636, 0.37373737, 0.38383838, 0.39393939,
#        0.4040404 , 0.41414141, 0.42424242, 0.43434343, 0.44444444,
#        0.45454545, 0.46464646, 0.47474747, 0.48484848, 0.49494949,
#        0.50505051, 0.51515152, 0.52525253, 0.53535354, 0.54545455,
#        0.55555556, 0.56565657, 0.57575758, 0.58585859, 0.5959596 ,
#        0.60606061, 0.61616162, 0.62626263, 0.63636364, 0.64646465,
#        0.65656566, 0.66666667, 0.67676768, 0.68686869, 0.6969697 ,
# ...

# %%
#Does appear to be summing to 1
simps(joint(100, 60, x) / simps(joint(100, 60, x), dx=x[1]-x[0]), dx =x[1]-x[0])
# Out:
# 0.9999999999999998
